# %%
import pyclamd

# %%
cd = pyclamd.ClamdAgnostic()

# %%
cd.ping()
# Out:
# True

# %%
r = cd.multiscan_file('D:\WeGameApps')

# %%
cd.multiscan_file('D:\\')
# Out:
# {'D:\\DumpStack.log.tmp': ('ERROR', 'Access denied.'),
#  'D:\\DevelopSoftwares\\web\\mysql-8.0.31-winx64\\data\\#ib_16384_1.dblwr': ('ERROR',
#   'File path check failure: Unknown error.'),
#  'D:\\DevelopSoftwares\\web\\mysql-8.0.31-winx64\\data\\undo_001': ('ERROR',
#   'File path check failure: Unknown error.'),
#  'D:\\DevelopSoftwares\\web\\mysql-8.0.31-winx64\\data\\undo_002': ('ERROR',
#   'File path check failure: Unknown error.'),
#  'D:\\DevelopSoftwares\\web\\mysql-8.0.31-winx64\\data\\xuan.err': ('ERROR',
#   'File path check failure: Unknown error.'),
#  'D:\\DevelopSoftwares\\web\\mysql-8.0.31-winx64\\data\\#ib_16384_0.dblwr': ('ERROR',
#   'File path check failure: Unknown error.'),
#  'D:\\DevelopSoftwares\\web\\mysql-8.0.31-winx64\\data\\binlog.000007': ('ERROR',
#   'File path check failure: Unknown error.'),
#  'D:\\DevelopSoftwares\\web\\mysql-8.0.31-winx64\\data\\binlog.index': ('ERROR',
#   'File path check failure: Unknown error.'),
# ...

# %%
for i in result:
    if result[i][0]=='FOUND':
        print(i,':',result[i])
# Out:
# D:\masm32\bin\zoomin.exe : ('FOUND', 'Win.Virus.Ramnit-9958537-0')
# D:\Program Files (x86)\WeGame\tcls\Tenio\VFS.dll : ('FOUND', 'Win.Trojan.Ramnit-9872325-0')
# D:\Program Files (x86)\WeGame\apps\Cross\Core\Stable\Tenio\VFS.dll : ('FOUND', 'Win.Trojan.Ramnit-9872325-0')
# D:\Program Files (x86)\Tencent\QQ\Bin\TSSafeEdit.dat : ('FOUND', 'Win.Trojan.Generic-9949185-0')
# D:\Softwares\wsl-terminal\run-wsl-file.exe : ('FOUND', 'Win.Malware.Misc-9950733-0')
# D:\Softwares\wsl-terminal\emacs.exe : ('FOUND', 'Win.Malware.Misc-9950733-0')
# D:\Softwares\wsl-terminal\open-wsl.exe : ('FOUND', 'Win.Malware.Misc-9950733-0')
# D:\Softwares\wsl-terminal\vim.exe : ('FOUND', 'Win.Malware.Misc-9950733-0')
# D:\Users\czx\Desktop\documents\创作\比赛作品-课堂展示\北京市电赛\【正点原子】战舰STM32F103开发板\【正点原子】战舰STM32F103开发板资料 资料盘(A盘)\6，软件资料\1，软件\字库制作软件.rar : ('FOUND', 'Win.Trojan.Bifrose-2073')
# D:\Users\czx\Desktop\网安实践\code\virus copy.txt : ('FOUND', 'Win.Test.EICAR_HDB-1')
# ...
